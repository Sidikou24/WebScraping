# %%
import requests
from bs4 import BeautifulSoup

# Send a GET request to the website
url = 'https://openclassrooms.com/fr/courses/4425066-concevez-un-site-avec-flask'
response = requests.get(url)

# Create a BeautifulSoup object
soup = BeautifulSoup(response.text, 'html.parser')

# Find and extract specific elements from the webpage
title = soup.title.text
paragraphs = soup.find_all('p')

# Print the extracted data
print('Title:', title)
print('Paragraphs:')
for p in paragraphs:
    print(p.text)
# Out:
# Title:
#                             Concevez un site avec Flask - OpenClassrooms
#
# Paragraphs:
#
# Vous utilisez un navigateur obsolète, veuillez le mettre à jour.
#
#
#                 Veuillez utiliser un navigateur internet moderne avec JavaScript activé pour naviguer sur OpenClassrooms.com
#
# Ce cours est visible gratuitement en ligne.
# course.header.alt.is_video
#
# course.header.alt.is_certifying
#
#
# Mis à jour le 18/02/2022
# Vous avez une idée d’application web mais vous ne savez pas comment la réaliser ? Vous cherchez une alternative simple à Django ?
# Découvrez Flask, le micro-framework écrit en Python qui vous permet de créer une application web en 7 lignes de code !
# Dans ce cours vous apprendrez à :
# créer une application avec Flask en développant vos premières fonctionnalités ;
# tester votre application avec des tests fonctionnels ;
# à mettre en ligne votre application Flask.
# Vous êtes prêt ? Commençons !
# Objectifs pédagogiques :
# Créer une application web avec Flask
# Organiser un projet MVT (Modèle / Vue / Template)
# Utiliser un ORM pour interagir avec une base de données
# Tester un parcours utilisateur avec des tests fonctionnels et Selenium
# Mettre en ligne une application Flask sur Heroku
# Prérequis :
# Démarrez votre projet avec Python
# Découvrez la programmation orientée objet avec Python
# Le chapitre du cours "Gérez du code avec Git et GitHub"  (pour récupérer le code du cours)
# Outils :
# Console
# GitHub
#
# Très heureux de voir que nos cours vous plaisent, déjà 5 pages lues aujourd'hui ! Vous pouvez continuer la lecture de nos cours en devenant un membre de la communauté d'OpenClassrooms. C'est gratuit !
#
#
# Vous pourrez aussi suivre votre avancement dans le cours, faire les exercices et discuter avec les autres membres.
#
#
# Le téléchargement des vidéos de nos cours est accessible pour les membres Premium. Vous pouvez toutefois les visionner en streaming gratuitement.
#
#
# Le téléchargement des vidéos de nos cours est accessible pour les membres Premium. Vous pouvez toutefois les visionner en streaming gratuitement.
#
#
# OpenClassrooms, Leading E-Learning Platform
#
#
# Développeuse freelance, entrepreneure et formatrice. Diplômée du Master Grande École d'Audencia.
